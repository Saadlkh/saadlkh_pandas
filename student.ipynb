# %%
import pandas as pd

# %%
pd.read_csv("data.csv")
# Out:
#     Unnamed: 0             nom le verbe de nom masculin ou féminin  \
# 0            0       digestion          digere             féminin
# 1            1    alimentation       alimenter             féminin
# 2            2        eduction         eduquer             féminin
# 3            3         aliment         aliment            masculin
# 4            4  transformation     transformer             féminin
# 5            5            tube           tuber            masculin
# 6            6          organe       organiser            masculin
# 7            7    malnutrition      malnourrir             féminin
# 8            8      equilibree      equilibrer             féminin
# 9            9        appareil     appareiller            masculin
# 10          10        glucides        glucider            masculin
# 11          11         lipides       lipidiser            masculin
# 12          12        protides        protider            masculin
# ...
