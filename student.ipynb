# %%
import pandas as pd

# %%
data = {
    "nom": [
        "complet", "incomplet", "molecule", "mise",
        "evidence", "filtart", "vapeur", "precipite",
        "indicateur", "anus"
    ],
    "le verbe de nom": [
        "compléter", "incompléter", "moléculer", "mettre",
        "évidencer", "filtrer", "vaporiser", "précipiter",
        "indiquer", "anusser"
    ],
    "masculin ou féminin": [
        "masculin", "masculin", "féminin", "féminin",
        "féminin", "masculin", "féminin", "masculin",
        "masculin", "masculin"
    ],
    "Expliqué en arabe": [
        "كامل", "غير كامل", "جزيء", "وضع",
        "دليل", "ترشيح", "بخار", "رواسب",
        "مؤشر", "شرج"
    ]
}

# Create DataFrame
b = pd.DataFrame(data)
b
# Out:
#           nom le verbe de nom masculin ou féminin Expliqué en arabe
# 0     complet       compléter            masculin              كامل
# 1   incomplet     incompléter            masculin          غير كامل
# 2    molecule       moléculer             féminin              جزيء
# 3        mise          mettre             féminin               وضع
# 4    evidence       évidencer             féminin              دليل
# 5     filtart         filtrer            masculin             ترشيح
# 6      vapeur       vaporiser             féminin              بخار
# 7   precipite      précipiter            masculin             رواسب
# 8  indicateur        indiquer            masculin              مؤشر
# 9        anus         anusser            masculin               شرج

# %%
a = pd.read_csv("noms_data_arabic.csv")
a
# Out:
#                nom le verbe de nom masculin ou féminin Expliqué en arabe
# 0        digestion          digere             féminin       عملية الهضم
# 1     alimentation       alimenter             féminin           التغذية
# 2         eduction         eduquer             féminin           التعليم
# 3          aliment         aliment            masculin   المادة الغذائية
# 4   transformation     transformer             féminin            التحول
# 5             tube           tuber            masculin             أنبوب
# 6           organe       organiser            masculin               عضو
# 7     malnutrition      malnourrir             féminin       سوء التغذية
# 8       equilibree      equilibrer             féminin            متوازن
# 9         appareil     appareiller            masculin              جهاز
# 10        glucides        glucider            masculin      الكربوهيدرات
# 11         lipides       lipidiser            masculin            الدهون
# ...

# %%
y = pd.concat([a, b], ignore_index=True)
y
# Out:
#                nom le verbe de nom masculin ou féminin Expliqué en arabe
# 0        digestion          digere             féminin       عملية الهضم
# 1     alimentation       alimenter             féminin           التغذية
# 2         eduction         eduquer             féminin           التعليم
# 3          aliment         aliment            masculin   المادة الغذائية
# 4   transformation     transformer             féminin            التحول
# 5             tube           tuber            masculin             أنبوب
# 6           organe       organiser            masculin               عضو
# 7     malnutrition      malnourrir             féminin       سوء التغذية
# 8       equilibree      equilibrer             féminin            متوازن
# 9         appareil     appareiller            masculin              جهاز
# 10        glucides        glucider            masculin      الكربوهيدرات
# 11         lipides       lipidiser            masculin            الدهون
# ...
